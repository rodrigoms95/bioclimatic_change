# %%
import os

import pandas as pd
import numpy as np

import geopandas as gpd
import xarray as xr
import rioxarray as rxr

import geoviews as gv

# %%
path_d  = "../data/"
path_WC = path_d + "WC/"

ftype = [ "Historical", "Future" ]
fhead = "wc2.1_"
tif = ".tif"
res = [ "10m", "30s" ]
vars = [ "tavg", "tmax", "tmin", "prec", "vapr", "srad", "elev" ]
month = [ f"{x:02d}" for x in range(1, 13) ]

# %%
fname
# Out:
# '../data/WC/wc2.1_10m_prec/wc2.1_10m_prec_01.tif'

# %%
h = 0
i = 0
j = 3
k = 0

fname = ( path_WC + ftype[h] + "/" + fhead + res[i] + "_" + vars[j] + "/"
    + fhead + res[i] + "_" + vars[j] + "_" + month[k] + tif )

ds = rxr.open_rasterio( fname )

ds
# Out:
# <xarray.DataArray (band: 1, y: 1080, x: 2160)>
# [2332800 values with dtype=int16]
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -179.9 -179.8 -179.6 -179.4 ... 179.6 179.7 179.9
#   * y            (y) float64 89.92 89.75 89.58 89.42 ... -89.58 -89.75 -89.92
#     spatial_ref  int64 0
# Attributes:
#     STATISTICS_MAXIMUM:  908
#     STATISTICS_MEAN:     1.#SNAN
#     STATISTICS_MINIMUM:  0
#     STATISTICS_STDDEV:   1.#SNAN
#     _FillValue:          -32768.0
#     scale_factor:        1.0
#     add_offset:          0.0
